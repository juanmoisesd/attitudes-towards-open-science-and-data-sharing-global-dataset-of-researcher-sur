# %% [markdown]
# # Attitudes towards Open Science and Data Sharing: Global Dataset of Researcher Surveys (2018-2024)
#
# **DOI:** [10.5281/zenodo.18881242](https://doi.org/10.5281/zenodo.18881242)
# **Author:** de la Serna Tuya, Juan Moisés · ORCID: 0000-0002-8401-8018
# **License:** CC0 1.0
#
# ---
#
# This dataset compiles quantitative data from international surveys (2018-2024) on attitudes of academic researchers towards open science and data sharing. Includes five key analytical dimensions: (1) Willingness to share data by discipline; (2) Repository awareness and use rates (Zenodo, Dataverse, OSF, Figshare, Dryad, GitHub); (3) Perceived barriers (legal/ethical issues, lack of recognition, ef
#
# **Keywords:** open science, data sharing, GDP

# %%
# Install dependencies if needed
# !pip install pandas matplotlib seaborn numpy

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 120
print('Libraries loaded.')

# %% [markdown]
# ## 1. Load Dataset

# %%
# Download from: https://doi.org/10.5281/zenodo.18881242
# df = pd.read_csv('dataset.csv')

# Synthetic example data
np.random.seed(42)
years = list(range(2000, 2024))
keywords = ['open science', 'data sharing', 'GDP']
df = pd.DataFrame({'year': years,
    **{k.replace(' ','_')[:12]: np.random.normal(50,15,len(years)) for k in keywords}})

print(f'Dataset: Attitudes towards Open Science and Data Sharing: G')
print(f'DOI: 10.5281/zenodo.18881242')
print(f'Shape: {df.shape}')
df.head()

# %% [markdown]
# ## 2. Summary Statistics

# %%
df.describe().round(2)

# %% [markdown]
# ## 3. Temporal Trends

# %%
fig, ax = plt.subplots(figsize=(10,5))
for col in df.columns[1:]:
    ax.plot(df['year'], df[col], marker='o', markersize=3, label=col)
ax.set_title('Attitudes towards Open Science and Data Sharing: Global')
ax.set_xlabel('Year')
ax.set_ylabel('Value')
ax.legend(fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Citation

# %%
print('APA:')
print('de la Serna Tuya, Juan Moisés (2026). Attitudes towards Open Science and Data Sharing: Global Dataset of Res. Zenodo. https://doi.org/10.5281/zenodo.18881242')
